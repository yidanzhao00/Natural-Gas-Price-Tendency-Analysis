# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from pathlib import Path
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
#loading the file
us_weather_df = pd.read_csv("C:/Users/zhaoy/Documents/ECON_611_Uniper_Project/ECON-611-Uniper-Project/data_files/Monthly_data/US_weather_data/combined_us_weather.csv")
ca_weather_df = pd.read_csv("C:/Users/zhaoy/Documents/ECON_611_Uniper_Project/ECON-611-Uniper-Project/data_files/Monthly_data/CA_weather_data/combined_ca_weather.csv", encoding='ISO-8859-1')
ab_weather_df = pd.read_csv("C:/Users/zhaoy/Documents/ECON_611_Uniper_Project/ECON-611-Uniper-Project/data_files/monthly_data/CA_weather_data/alberta_weather.csv", encoding='ISO-8859-1')

# %%
monthly_df = pd.read_csv("C:/Users/zhaoy/Documents/ECON_611_Uniper_Project/ECON-611-Uniper-Project/data_files/Monthly_data/Monthly_data.csv")

# %%
monthly_df.isnull().sum()
# Out:
# DATE                                     0
# CA_Inflation                             1
# All-items excluding food and energy 7    0
# US_CPI                                   0
# US_Interest_Rate                         0
# CA_Interest_rate                         0
# WCS_US                                   1
# WTI_US                                   1
# CADUSD                                   0
# WTI (CAD/bbl)                            0
# Edmonton Light (CAD/bbl)                 0
# WCS (CAD/bbl)                            0
# LLS (CAD/bbl)                            0
# Brent (CAD/bbl)                          0
# Crude Oil - Light                        0
# Crude Oil - Medium                       0
# Crude Oil - Heavy                        0
# Crude Oil - Ultra Heavy                  0
# dtype: int64

# %%
daily_df = pd.read_csv("C:/Users/zhaoy/Documents/ECON_611_Uniper_Project/ECON-611-Uniper-Project/data_files/Daily_data/Daily_data.csv")
daily_df2 = pd.read_csv("C:/Users/zhaoy/Documents/ECON_611_Uniper_Project/ECON-611-Uniper-Project/data_files/Daily_data/Daily_data(cleaned).csv")

# %%
daily_df.isnull().sum()
# Out:
# Date                                                 0
# Henry USD/MMBtu                                    365
# AECO 5A USD/MMBtu                                  365
# AECO 5A Cad/GJ                                     365
# Electricity_Daily_Average                            0
# Electricity_Daily_On_Peak_Average                    0
# Electricity_Daily_Off_Peak_Average                   0
# Electricity_30Ravg Average                           0
# Electricity_30Ravg_On_Peak_Average                   0
# Electricity_30Ravg_ Off_Peak_Average                 0
# Measured Receipts Volume (103M3)                    31
# NGTL_Storage_Receipts_Volume_(103M3)                31
# NGTL_Gordondale_Receipts_Volume_(103M3)             31
# NGTL_Groundbirch_East_Receipts_Volume_(103M3)       31
# NGTL_Intra_Provincial_Deliveries_Volume_(103M3)     31
# NGTL_Border_Deliveries_Volume_(103M3)               31
# NGTL_Empress_Deliveries_Volume_(103M3)              31
# ...

# %%
daily_df.describe
# Out:
# <bound method NDFrame.describe of             Date  Henry USD/MMBtu  AECO 5A USD/MMBtu  AECO 5A Cad/GJ  \
# 0       1/1/2017              NaN                NaN             NaN
# 1       1/2/2017              NaN                NaN             NaN
# 2       1/3/2017              NaN                NaN             NaN
# 3       1/4/2017              NaN                NaN             NaN
# 4       1/5/2017              NaN                NaN             NaN
# ...          ...              ...                ...             ...
# 2551  12/27/2023            2.480             1.2793          1.6009
# 2552  12/28/2023            2.625             1.3343          1.6700
# 2553  12/29/2023            2.550             1.3208          1.6531
# 2554  12/30/2023            2.550             1.3208          1.6531
# 2555  12/31/2023            2.550             1.3208          1.6531
#
#       Electricity_Daily_Average  Electricity_Daily_On_Peak_Average  \
# ...

# %%
daily_df2.isnull().sum()
# Out:
# date                                               0
# henry_usd/mmbtu                                    0
# aeco_5a_usd/mmbtu                                  0
# aeco_5a_cad/gj                                     0
# electricity_daily_average                          0
# electricity_daily_on_peak_average                  0
# electricity_daily_off_peak_average                 0
# electricity_30ravg_average                         0
# electricity_30ravg_on_peak_average                 0
# electricity_30ravg__off_peak_average               0
# measured_receipts_volume_(103m3)                   0
# ngtl_storage_receipts_volume_(103m3)               0
# ngtl_gordondale_receipts_volume_(103m3)            0
# ngtl_groundbirch_east_receipts_volume_(103m3)      0
# ngtl_intra_provincial_deliveries_volume_(103m3)    0
# ngtl_border_deliveries_volume_(103m3)              0
# ngtl_empress_deliveries_volume_(103m3)             0
# ngtl_abc_deliveries_volume_(103m3)                 0
# ...

# %%
daily_df2.describe
# Out:
# <bound method NDFrame.describe of             date  henry_usd/mmbtu  aeco_5a_usd/mmbtu  aeco_5a_cad/gj  \
# 0     2018-01-01            3.580             2.8248          3.3518
# 1     2018-01-02            3.580             1.7509          2.0754
# 2     2018-01-03            6.625             1.5555          1.8480
# 3     2018-01-04            6.875             1.5478          1.8377
# 4     2018-01-05            4.420             1.3134          1.5431
# ...          ...              ...                ...             ...
# 2155  2023-11-26            2.715             1.9322          2.5153
# 2156  2023-11-27            2.715             1.8144          2.3449
# 2157  2023-11-28            2.735             1.9060          2.4505
# 2158  2023-11-29            2.785             1.8903          2.4360
# 2159  2023-11-30            2.700             1.8949          2.4403
#
#       electricity_daily_average  electricity_daily_on_peak_average  \
# ...

# %%
us_weather_df.head()
# Out:
#                                        NAME      DATE  AWND  PRCP  SNOW  SNWD  \
# 0  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US  1/1/2017   2.8   0.0   0.0   0.0
# 1  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US  1/2/2017   2.4   0.0   0.0   0.0
# 2  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US  1/3/2017   1.4   0.0   0.0   0.0
# 3  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US  1/4/2017   3.8   0.0   0.0   0.0
# 4  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US  1/5/2017   5.6   0.0   0.0   0.0
#
#    TMAX  TMIN
# 0  10.0   0.6
# 1   6.1  -0.5
# 2  10.0  -0.5
# 3  13.3  -0.5
# 4  13.9   2.2

# %%
daily_df.columns=daily_df.columns.str.replace(' ', '_')

# %%
daily_df.dtypes
# Out:
# Date                                                object
# Henry USD/MMBtu                                    float64
# AECO 5A USD/MMBtu                                  float64
# AECO 5A Cad/GJ                                     float64
# Electricity_Daily_Average                          float64
# Electricity_Daily_On_Peak_Average                  float64
# Electricity_Daily_Off_Peak_Average                 float64
# Electricity_30Ravg Average                         float64
# Electricity_30Ravg_On_Peak_Average                 float64
# Electricity_30Ravg_ Off_Peak_Average               float64
# Measured Receipts Volume (103M3)                   float64
# NGTL_Storage_Receipts_Volume_(103M3)               float64
# NGTL_Gordondale_Receipts_Volume_(103M3)            float64
# NGTL_Groundbirch_East_Receipts_Volume_(103M3)      float64
# NGTL_Intra_Provincial_Deliveries_Volume_(103M3)    float64
# NGTL_Border_Deliveries_Volume_(103M3)              float64
# ...

# %%
daily_df['Date'] = pd.to_datetime(daily_df['Date'])

# %%
daily_df.dtypes
# Out:
# Date                                               datetime64[ns]
# Henry_USD/MMBtu                                           float64
# AECO_5A_USD/MMBtu                                         float64
# AECO_5A_Cad/GJ                                            float64
# Electricity_Daily_Average                                 float64
# Electricity_Daily_On_Peak_Average                         float64
# Electricity_Daily_Off_Peak_Average                        float64
# Electricity_30Ravg_Average                                float64
# Electricity_30Ravg_On_Peak_Average                        float64
# Electricity_30Ravg__Off_Peak_Average                      float64
# Measured_Receipts_Volume_(103M3)                          float64
# NGTL_Storage_Receipts_Volume_(103M3)                      float64
# NGTL_Gordondale_Receipts_Volume_(103M3)                   float64
# NGTL_Groundbirch_East_Receipts_Volume_(103M3)             float64
# ...

# %%
monthly_df.CA_Inflation
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22836\3588567675.py in <module>
# ----> 1 monthly_df.CA_Inflation
#
# ~\anaconda3\envs\tf2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'CA_Inflation'

# %%
daily_df.head()
# Out:
#         Date  Henry_USD/MMBtu  AECO_5A_USD/MMBtu  AECO_5A_Cad/GJ  \
# 0 2017-01-01              NaN                NaN             NaN
# 1 2017-01-02              NaN                NaN             NaN
# 2 2017-01-03              NaN                NaN             NaN
# 3 2017-01-04              NaN                NaN             NaN
# 4 2017-01-05              NaN                NaN             NaN
#
#    Electricity_Daily_Average  Electricity_Daily_On_Peak_Average  \
# 0                      19.31                              20.85
# 1                      29.85                              34.20
# 2                      25.87                              27.42
# 3                      25.76                              29.11
# 4                      19.42                              19.78
#
#    Electricity_Daily_Off_Peak_Average  Electricity_30Ravg_Average  \
# 0                               16.23                       24.31
# ...

# %%
ca_weather_df.head()
# Out:
#   Station Name Date/Time  Year  Month  Day  Max Temp (°C)  Min Temp (°C)  \
# 0     BANFF CS  1/1/2017  2017      1    1           -8.2          -18.4
# 1     BANFF CS  1/2/2017  2017      1    2          -17.3          -31.0
# 2     BANFF CS  1/3/2017  2017      1    3          -19.3          -36.7
# 3     BANFF CS  1/4/2017  2017      1    4          -15.2          -31.6
# 4     BANFF CS  1/5/2017  2017      1    5          -10.2          -15.6
#
#    Mean Temp (°C)  Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  \
# 0           -13.3                31.3                 0.0              NaN
# 1           -24.2                42.2                 0.0              NaN
# 2           -28.0                46.0                 0.0              NaN
# 3           -23.4                41.4                 0.0              NaN
# 4           -12.9                30.9                 0.0              NaN
#
#    Total Snow (cm)  Total Precip (mm)  Snow on Grnd (cm)  \
# ...

# %%
ab_weather_df.head()
# Out:
#     Township      Date  Air Temp. Min. (°C)  Air Temp. Max. (°C)  \
# 0  T009R21W4  1/1/2017               -14.94                -4.96
# 1  T009R21W4  1/2/2017               -24.37               -13.47
# 2  T009R21W4  1/3/2017               -29.41               -17.53
# 3  T009R21W4  1/4/2017               -23.66               -10.17
# 4  T009R21W4  1/5/2017               -20.93                -4.17
#
#    Precip. (mm)  Precip. Accumulated (mm)  Relative Humidity Avg. (%)  \
# 0          1.30                      1.30                       89.79
# 1          0.27                      1.57                       85.18
# 2          0.26                      1.83                       80.17
# 3          0.27                      2.10                       81.87
# 4          0.26                      2.36                       74.93
#
#    Modelled Snow Water Equiv. (mm)  Incoming Solar Rad. Total (MJ/m2)  \
# 0                            11.12                               3.13
# ...
